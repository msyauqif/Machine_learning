# %%
#IMPORT LIBRARY
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('botak.csv')

# %%
df
# Out:
#       umur jenis_kelamin       pekerjaan      provinsi          gaji  \
# 0     42.0     Laki-laki             PNS        Padang  7.864005e+06
# 1     33.0     Laki-laki  Pegawai swasta  Palangkaraya  6.492662e+06
# 2     59.0     Laki-laki       Freelance        Serang  8.086303e+06
# 3     38.0     Laki-laki  Pegawai swasta     Gorontalo  1.147321e+07
# 4     33.0     Perempuan       Freelance  Tanjungselor  1.475942e+07
# ...    ...           ...             ...           ...           ...
# 7986  31.0     Laki-laki  Pegawai swasta        Padang  2.911963e+07
# 7987  40.0     Perempuan  Pegawai swasta   Banjarmasin  8.955173e+06
# 7988  43.0     Perempuan             PNS       Mataram  4.022652e+06
# 7989  29.0     Laki-laki  Pegawai swasta        Serang  5.801753e+06
# 7990  55.0     Laki-laki  Pegawai swasta        Padang  8.518947e+06
#
#       is_menikah  is_keturunan      berat      tinggi            sampo  \
# ...

# %% [markdown]
# ## Diagram Batang: Rata-rata Gaji Berdasarkan Pendidikan

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(x="pendidikan", y="gaji", data=df, palette="coolwarm", hue=None, ax=ax)
ax.set_title("Rata-rata Gaji Berdasarkan Pendidikan", fontsize=14)
ax.set_xlabel("Pendidikan", fontsize=12)
ax.set_ylabel("Rata-rata Gaji", fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=12)
fig.text(0.5, 0.5, "Muhammad Syauqi Firdaus", fontsize=30, color='gray', alpha=0.2, ha='center', va='center', rotation=30)
plt.show()
# Out:
# /var/folders/4h/p2_xvknd0fx73wmck07bjmgh0000gn/T/ipykernel_93602/3200664111.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="pendidikan", y="gaji", data=df, palette="coolwarm", hue=None, ax=ax)
# /var/folders/4h/p2_xvknd0fx73wmck07bjmgh0000gn/T/ipykernel_93602/3200664111.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=12)

# %% [markdown]
# ## Diagram Garis: Tren Rata-rata Tinggi Badan Berdasarkan Usia

# %%
umur_tinggi = df.groupby("umur")["tinggi"].mean().reset_index()
fig, ax = plt.subplots(figsize=(10, 5))
sns.lineplot(x="umur", y="tinggi", data=umur_tinggi, marker="o", color="green", ax=ax)
ax.set_title("Tren Rata-rata Tinggi Badan Berdasarkan Usia", fontsize=14)
ax.set_xlabel("Umur", fontsize=12)
ax.set_ylabel("Tinggi Badan (cm)", fontsize=12)
fig.text(0.5, 0.5, "Muhammad Syauqi Firdaus", fontsize=30, color='gray', alpha=0.2, ha='center', va='center', rotation=30)
plt.show()

# %% [markdown]
# ## Diagram Lingkaran: Proporsi Responden Berdasarkan Jenis Kelamin

# %%
fig, ax = plt.subplots(figsize=(6, 6))
df["jenis_kelamin"].value_counts().plot.pie(autopct='%1.1f%%', colors=["red", "pink"], ax=ax)
ax.set_title("Proporsi Responden Berdasarkan Jenis Kelamin", fontsize=14)
fig.text(0.5, 0.5, "Muhammad Syauqi Firdaus", fontsize=30, color='gray', alpha=0.2, ha='center', va='center', rotation=30)
ax.set_ylabel("")
plt.show()
